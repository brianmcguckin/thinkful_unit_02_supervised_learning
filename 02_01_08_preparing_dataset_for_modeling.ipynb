# %% [markdown]
# ## Challenge: Preparing a dataset for modeling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import math
from matplotlib.mlab import PCA as mlabPCA
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# Using a dataset of your choice, select an outcome variable and then pick four or five other variables (one to two categorical, three to four continuous) to act as the basis for features. Explore the variables using the univariate and bivariate methods you've learned so far.

# %%
train = pd.read_csv('train.csv')
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %% [markdown]
# __Outcome variable:__ SalePrice
#
# __Categorical variables:__ Neighborhood
#
# __Continuous variables:__ OverallQual, GrLivArea, GarageCars, FullBath

# %% [markdown]
# ## Bivariate exploration

# %%
df = train[['Neighborhood','OverallQual','GrLivArea','GarageCars','FullBath','SalePrice']].copy()

#add jitter
df_jittered = df.loc[:,'OverallQual':'SalePrice'].dropna()
jitter = pd.DataFrame(np.random.uniform(-.3,.3,size=(df_jittered.shape)),
                     columns=df_jittered.columns)
df_jittered = df_jittered.add(jitter)

#make scatterplot matrix
g = sns.PairGrid(df_jittered.dropna(), diag_sharey=False)
g.map_upper(plt.scatter, alpha=.5)
g.map_lower(sns.regplot, scatter_kws=dict(alpha=0))
g.map_diag(sns.kdeplot, lw=3)
plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
#correlation matrix
corrmat = df.corr()
print(corrmat)

f, ax = plt.subplots(figsize=(12,9))
sns.heatmap(corrmat, vmax=.8, square=True)
plt.show()
# Out:
#              OverallQual  GrLivArea  GarageCars  FullBath  SalePrice
# OverallQual     1.000000   0.593007    0.600671  0.550600   0.790982
# GrLivArea       0.593007   1.000000    0.467247  0.630012   0.708624
# GarageCars      0.600671   0.467247    1.000000  0.469672   0.640409
# FullBath        0.550600   0.630012    0.469672  1.000000   0.560664
# SalePrice       0.790982   0.708624    0.640409  0.560664   1.000000

# %% [markdown]
# ## Principle Components Analysis

# %%
t = sns.regplot('OverallQual', 'GrLivArea', df,
                x_jitter=.49, y_jitter=.49, fit_reg=False)
t.axhline(0, color='k', linestyle='-', linewidth=2)
t.axvline(0, color='k', linestyle='-', linewidth=2)
t.axes.set_title('Raw data')
plt.show()

#subtract by mean and divide by std dev to set variables to same scale
df['OverallQual_z'] = (df['OverallQual'] - df['OverallQual'].mean()) / df['OverallQual'].std()
df['GrLivArea_z'] = (df['GrLivArea'] - df['GrLivArea'].mean()) / df['GrLivArea'].std()

t = sns.regplot('OverallQual_z', 'GrLivArea_z', df,
                x_jitter=.49, y_jitter=.49, line_kws={'color':'red'})
t.axhline(0, color='k', linestyle='-', linewidth=2)
t.axvline(0, color='k', linestyle='-', linewidth=2)
t.axes.set_title('Standardized data')
plt.show()

# %%
#rotate the standardized data
df['OverallQual_z_rot'] = math.cos(40) * df['OverallQual_z'] - math.sin(40) * df['GrLivArea_z']
df['GrLivArea_z_rot'] = math.sin(40) * df['OverallQual_z'] + math.cos(40) * df['GrLivArea_z']

t = sns.regplot('OverallQual_z_rot','GrLivArea_z_rot', df,
               x_jitter=.49, y_jitter=.49, fit_reg=False)
t.axhline(0, color='k', linestyle='-', linewidth=2)
t.axvline(0, color='k', linestyle='-', linewidth=2)
t.axes.set_title('Rotated standardized data')
plt.show()

# %% [markdown]
# Horizontal vector contains more variance and has a higher information value than the vertical vector

# %%
#drop missing values and text PCA can't handle
df_pca = df[['OverallQual','GrLivArea','GarageCars','FullBath','SalePrice']].copy().dropna()

#normalize the data for mean=0 and std=1
X = StandardScaler().fit_transform(df_pca)

#transpose X
Xt = X.T
Cx = np.cov(Xt)
print('Covariance Matrix:\n', Cx)
# Out:
# Covariance Matrix:
#  [[1.0006854  0.59341388 0.60108242 0.55097709 0.79152374]
#  [0.59341388 1.0006854  0.46756767 0.63044346 0.70911017]
#  [0.60108242 0.46756767 1.0006854  0.46999396 0.64084813]
#  [0.55097709 0.63044346 0.46999396 1.0006854  0.56104804]
#  [0.79152374 0.70911017 0.64084813 0.56104804 1.0006854 ]]

# %%
#calculate eigenvals and vecs
eig_val_cov, eig_vec_cov = np.linalg.eig(Cx)

for i in range(len(eig_val_cov)):
    eigvec_cov = eig_vec_cov[:, i].reshape(1, 5).T
    print('Eigenvector {}: \n{}'.format(i + 1, eigvec_cov))
    print('Eigenvalue {}: {}'.format(i + 1, eig_val_cov[i]))
    print(40 * '-')
    
print('The percentage of total variance in dataframe explained by each component\n',
     eig_val_cov / sum(eig_val_cov))
# Out:
# Eigenvector 1:
# [[-0.46684567]
#  [-0.44614977]
#  [-0.41268628]
#  [-0.4162256 ]
#  [-0.48933812]]
# Eigenvalue 1: 3.42003618382502
# ----------------------------------------
# Eigenvector 2:
# [[-0.49978235]
#  [-0.34231797]
#  [-0.12186105]
#  [ 0.13839234]
#  [ 0.77397252]]
# Eigenvalue 2: 0.17535839904969974
# ----------------------------------------
# Eigenvector 3:
# [[ 0.23931154]
#  [-0.44941632]
#  [ 0.61544233]
#  [-0.58093188]
#  [ 0.15653705]]
# Eigenvalue 3: 0.6123393839610294
# ----------------------------------------
# Eigenvector 4:
# [[ 0.34384483]
#  [ 0.2982567 ]
#  [-0.56119818]
#  [-0.58392723]
#  [ 0.36999901]]
# Eigenvalue 4: 0.4504249251354957
# ----------------------------------------
# Eigenvector 5:
# [[-0.59730515]
#  [ 0.62676687]
#  [ 0.34803344]
#  [-0.35937577]
#  [ 0.0105657 ]]
# Eigenvalue 5: 0.3452681128265619
# ----------------------------------------
# The %age of total variance in dataframe explained by each component
# ...

# %%
plt.plot(eig_val_cov)
plt.show()

# %% [markdown]
# Eigenvalues and plot show to keep only the first component

# %% [markdown]
# ## How new component correlates with old variables

# %%
#create P to transform Cx into Cy to get Y
P = eig_vec_cov[:,0]

#transform X into Y
Y = P.T.dot(Xt)

#combine for plots
data_to_plot = df_pca[['OverallQual','GrLivArea','GarageCars','FullBath','SalePrice']]
data_to_plot['Component'] = Y
data_to_plot = pd.melt(data_to_plot, id_vars='Component')

g = sns.FacetGrid(data_to_plot, col='variable', size=5, aspect=.5)
g = g.map(sns.regplot,'Component','value',
          x_jitter=.49,y_jitter=.49,fit_reg=False)
plt.show()

# %%
sklearn_pca = PCA(n_components=5)
Y_sklearn = sklearn_pca.fit_transform(X)

print('The percentage of total variance in the dataset explained by each component from sklearn PCA\n',
     sklearn_pca.explained_variance_ratio_)

#Compare sklearn solution to by hand
plt.plot(Y_sklearn[:,0],Y,'o')
plt.title('Comparing solutions')
plt.ylabel('Sklearn Component 1')
plt.xlabel('By-hand Component 1')
plt.show()
# Out:
# The percentage of total variance in the dataset explained by each component from sklearn PCA
#  [0.68353874 0.12238399 0.09002328 0.06900633 0.03504766]
